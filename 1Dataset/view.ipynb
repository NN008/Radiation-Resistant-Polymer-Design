# %%
import pandas as pd

# %%
df = pd.read_csv("PI1M_Tg_MAC.csv")

# %%
print(df)
# Out:
#                                                    SMILES         Name  \
# 0                       *CCC[Fe]CCCC(=O)OCCCCOCCCNCC(*)=O   PI1M_00000
# 1                              *CCCC1C=CNC2=CC=C2C(*)CCC1   PI1M_00001
# 2                              *CC(C)(C)CCCCCCC(C)C(=O)N*   PI1M_00004
# 3                *Oc1ccc(CCCNC(=O)NCCCC(=O)C(C)C(*)=O)cc1   PI1M_00005
# 4                                        *CC(*)C(C)(C)CCC   PI1M_00006
# ...                                                   ...          ...
# 924233            *CC(*)C(=O)/C=C/CC(C)=NC(=O)OCCOCCOCCOC  PI1M_995793
# 924234  *CC(*)(CCC(=O)Oc1ccc(/N=N/c2ccc(C#N)cc2)cc1)c1...  PI1M_995794
# 924235  *Oc1ccccc1NC(=O)c1ccc(/N=N/c2ccc(C(=O)OC(=O)CC...  PI1M_995795
# 924236            *CCN(CCOC(=O)NCCCCCCCCNC(=O)O*)CC(=O)OC  PI1M_995797
# 924237               *OP(=O)(Cl)c1ccc(C(O)c2ccc(*)cc2)cc1  PI1M_995798
#
#           MolWt  ExactMolWt  HeavyAtomMolWt  MolLogP    TPSA  NumHAcceptors  \
# ...

# %%
df = pd.read_csv("PI1M_with_Tg_Final.csv")
print(df)
